# %%
# !pip install roboflow
# !pip install ultralytics

# %%
from ultralytics import YOLO
from IPython.display import display, Image

# %%
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.148 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (NVIDIA A100-SXM4-40GB, 40514MiB)
# Setup complete ✅ (12 CPUs, 83.5 GB RAM, 24.4/78.2 GB disk)

# %%
# !pip install wandb

# %%
# !wandb login
# Out:
# wandb: Logging into wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize
# wandb: Paste an API key from your profile and hit enter, or press ctrl+c to quit:
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="kgqnptI40QlW5Hw5jljK")
project = rf.workspace("msc-project-evhfz").project("toys-rcbfu")
dataset = project.version(2).download("yolov8")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# Dependency ultralytics==8.0.134 is required but found version=8.0.148, to fix: `pip install ultralytics==8.0.134`
# ...
# Extracting Dataset Version Zip to Toys-2 in yolov8:: 100%|██████████| 475/475 [00:00<00:00, 7676.10it/s]

# %% [markdown]
# 第一轮 随机0 50

# %%
# 第一轮训练 随机0
# !yolo task=detect mode=train model=yolov8n.pt project=train_data name=scratch data=/content/datasets/Toys-2/data.yaml epochs=50 imgsz=640
# Out:
# ...
# 100% 6.23M/6.23M [00:00<00:00, 184MB/s]
# Ultralytics YOLOv8.0.148 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (NVIDIA A100-SXM4-40GB, 40514MiB)
# ...

# %% [markdown]
# 第二轮 随机0 100

# %%
# 第二轮训练 随机0 100
# !yolo task=detect mode=train model=/content/train_data/scratch/weights/best.pt project=train_data name=scratch_1 data=/content/datasets/Toys-2/data.yaml epochs=50 imgsz=640
# Out:
# Ultralytics YOLOv8.0.148 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (NVIDIA A100-SXM4-40GB, 40514MiB)
# ...

# %% [markdown]
# 第三轮 随机0 150

# %%
# 第三轮训练 随机0 150
# !yolo task=detect mode=train model=/content/train_data/scratch_1/weights/best.pt project=train_data name=scratch_2 data=/content/datasets/Toys-2/data.yaml epochs=50 imgsz=640
# Out:
# Ultralytics YOLOv8.0.148 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (NVIDIA A100-SXM4-40GB, 40514MiB)
# ...

# %% [markdown]
# 第四轮 随机0 200

# %%
# 第四轮训练 随机0 200
# !yolo task=detect mode=train model=/content/train_data/scratch_2/weights/best.pt project=train_data name=scratch_3 data=/content/datasets/Toys-2/data.yaml epochs=50 imgsz=640
# Out:
# Ultralytics YOLOv8.0.148 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (NVIDIA A100-SXM4-40GB, 40514MiB)
# ...

# %% [markdown]
# 第五轮 随机0 250

# %%
# 第五轮训练 随机0 250
# !yolo task=detect mode=train model=/content/train_data/scratch_3/weights/best.pt project=train_data name=scratch_4 data=/content/datasets/Toys-2/data.yaml epochs=50 imgsz=640
# Out:
# Ultralytics YOLOv8.0.148 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (NVIDIA A100-SXM4-40GB, 40514MiB)
# ...

# %% [markdown]
# 第一轮 随机1 50

# %%
# 第一轮训练 随机1 50
# !yolo task=detect mode=train model=yolov8n.pt close_mosaic=1 project=train_data name=scratch_1_0 data=/content/datasets/Toys-2/data.yaml epochs=50 imgsz=640
# Out:
# Ultralytics YOLOv8.0.148 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (NVIDIA A100-SXM4-40GB, 40514MiB)
# ...

# %% [markdown]
# 第二轮 随机1 100

# %%
# 第二轮训练 随机1 100
# !yolo task=detect mode=train model=/content/train_data/scratch_1_0/weights/best.pt close_mosaic=1 project=train_data name=scratch_1_1 data=/content/datasets/Toys-2/data.yaml epochs=50 imgsz=640
# Out:
# Ultralytics YOLOv8.0.148 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (NVIDIA A100-SXM4-40GB, 40514MiB)
# ...

# %% [markdown]
# 第一轮 迁移0 50

# %%
# 第一轮训练 迁移0 50
# !yolo task=detect mode=train model=yolov8n.pt pretrained=True project=train_data name=pretrain data=/content/datasets/Toys-2/data.yaml epochs=50 imgsz=640
# Out:
# Ultralytics YOLOv8.0.148 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (NVIDIA A100-SXM4-40GB, 40514MiB)
# ...

# %% [markdown]
# 第二轮训练 迁移0 100

# %%
# !rm -rf /content/train_data/pretrain_2

# %%
# 第二轮训练 迁移0 100
# !yolo task=detect mode=train model=/content/train_data/pretrain/weights/best.pt project=train_data name=pretrain_1 data=/content/datasets/Toys-2/data.yaml epochs=50 imgsz=640
# Out:
# Ultralytics YOLOv8.0.148 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (NVIDIA A100-SXM4-40GB, 40514MiB)
# ...

# %% [markdown]
# 第三轮 迁移0 150

# %%
# 第三轮训练 迁移0 150
# !yolo task=detect mode=train model=/content/train_data/pretrain_1/weights/best.pt project=train_data name=pretrain_2 data=/content/datasets/Toys-2/data.yaml epochs=50 imgsz=640
# Out:
# Ultralytics YOLOv8.0.148 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (NVIDIA A100-SXM4-40GB, 40514MiB)
# ...

# %% [markdown]
# 第四轮 迁移0 200

# %%
# 第三轮训练 迁移0 150
# !yolo task=detect mode=train model=/content/train_data/pretrain_2/weights/best.pt project=train_data name=pretrain_3 data=/content/datasets/Toys-2/data.yaml epochs=50 imgsz=640
# Out:
# Ultralytics YOLOv8.0.148 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (NVIDIA A100-SXM4-40GB, 40514MiB)
# ...

# %% [markdown]
# 第一轮 迁移1 50

# %%
# 第一轮训练 迁移1 50
# !yolo task=detect mode=train model=yolov8n.pt close_mosaic=1 pretrained=True project=train_data name=pretrain_1_0 data="/content/datasets/Toys-2/data.yaml" epochs=50 imgsz=640
# Out:
# Ultralytics YOLOv8.0.148 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (NVIDIA A100-SXM4-40GB, 40514MiB)
# ...

# %%
# 最终结果图
Image(filename=f'/content/train_data/pretrain_test/results.png', width=600)

# %%
# 最终测试积木
# !yolo detect mode=predict model=/content/train_data/pretrain_1_0/weights/best.pt source=/content/test_block.JPG
# Out:
# Ultralytics YOLOv8.0.148 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (NVIDIA A100-SXM4-40GB, 40514MiB)
# Model summary (fused): 168 layers, 3006038 parameters, 0 gradients
#
# image 1/1 /content/test_block.JPG: 640x640 5 toyblocks, 6.5ms
# Speed: 7.0ms preprocess, 6.5ms inference, 105.3ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/predict23

# %%
# 最终测试球
# !yolo detect mode=predict model=/content/train_data/pretrain_1_0/weights/best.pt source=/content/test_ball.JPG
# Out:
# Ultralytics YOLOv8.0.148 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (NVIDIA A100-SXM4-40GB, 40514MiB)
# Model summary (fused): 168 layers, 3006038 parameters, 0 gradients
#
# image 1/1 /content/test_ball.JPG: 640x640 3 toyballs, 6.7ms
# Speed: 6.7ms preprocess, 6.7ms inference, 90.6ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/predict24
